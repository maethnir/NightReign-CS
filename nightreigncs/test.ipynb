# %%
import pandas as pd

# %%
data = pd.read_csv("nightreigncs/static/images/Damages/SPREAD.csv", sep=";")
data.head()
# Out:
#                            Nightlord  Standard  Slash  Strike  Pierce  Magic  \
# 0  Heolstor, the Nightlord (Phase 1)         0     15     -10      10      0
# 1            Caligo, Miasma of Night         0    -15      15     -10    -20
# 2       Libra, Creature of the Night         0     10       0       0    -20
# 3     Fulghor, Champion of Nightglow         0      0       0       0      0
# 4             Maris, Fathom of Night         0     15     -20     -10    -20
#
#    Fire  Lightning  Holy  Poison  Rot  Bleed  Frostbite  Sleep  Madness
# 0    20          0    35       0  252      0          0    541        0
# 1    35        -20   -20     252  252    252        541    541        0
# 2    20          0    35     154  154    252        252      0      154
# 3     0         20   -30     154  154    154        154    154        0
# 4   -50         40   -15       0  252      0        252      0        0

# %%
for index, row in data.iterrows():
    print(row)
# Out:
# Nightlord    Heolstor, the Nightlord (Phase 1)
# Standard                                     0
# Slash                                       15
# Strike                                     -10
# Pierce                                      10
# Magic                                        0
# Fire                                        20
# Lightning                                    0
# Holy                                        35
# Poison                                       0
# Rot                                        252
# Bleed                                        0
# Frostbite                                    0
# Sleep                                      541
# Madness                                      0
# Name: 0, dtype: object
# Nightlord    Caligo, Miasma of Night
# Standard                           0
# Slash                            -15
# Strike                            15
# Pierce                           -10
# Magic                            -20
# ...
